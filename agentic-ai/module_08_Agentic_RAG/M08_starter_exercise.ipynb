# %% [markdown]
# # [STARTER] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(OPENAI_API_KEY)
db
# Out:
# VectorStoreManager():<chromadb.api.client.Client object at 0x739e4728ba10>

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM(
    model="gpt-4o-mini",
    temperature=0.3,
)

# %%
# TODO: Add the games pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method

games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name="games_market",
        pdf_path="TheGamingIndustry2024.pdf"
    )
)
# Out:
# VectorStore `games_market` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke(
    "What's the  state of virtual reality"
)
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by significant advancements and growing integration into the gaming industry. VR technology allows gamers to immerse themselves in interactive digital environments, enhancing the gaming experience beyond traditional boundaries. Notable examples include games like "Half-Life: Alyx," which utilize high-fidelity graphics, intuitive controls, and immersive audio to create realistic experiences. Additionally, VR is being leveraged in educational settings, therapy, and rehabilitation, indicating its expanding influence beyond entertainment. Overall, VR is a transformative technology that is reshaping how players engage with games and interact with digital worlds.

# %%
# TODO: Add the electric vehicles pdf file path with the extenstion .pdf
# And define a store name in load_pdf() method

electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name="electric_vehicles",
        pdf_path="GlobalEVOutlook2025.pdf"
    )
)
# Out:
# VectorStore `electric_vehicles` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil saw nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
# TODO: Define a tool that returns result.get_final_state()["answer"]
# DONOT Forget about defining the tool docstrings
@tool
def search_global_ev_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: Global EV Outlook 2025
    Publisher: International Energy Agency
    Release: May 2025
    ```
        The Global EV Outlook is an annual publication that reports on recent
        developments in electric mobility around the world. It is developed with the support
        of members of the Electric Vehicles Initiative (EVI).
    ```

    args:
        query (str): Search query
    """
    result:Run = electric_vehicles_rag.invoke(query)    
    return result.get_final_state()["answer"]

# %%
# TODO: Define a tool that returns result.get_final_state()["answer"]
# DONOT Forget about defining the tool docstrings
@tool
def search_games_market_report_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: The Gaming Industry in 2024 - Trends, Technologies & Predictions
    Publisher: Ixie Gaming
    Release: 2024
    ```
        The gaming industry, on the brink of transformative change due to technological
        advancements, is redefining entertainment and social interaction with
        immersive, personalized, and interactive experiences.
    ```

    args:
        query (str): Search query
    """
    result:Run = games_market_rag.invoke(query)    
    return result.get_final_state()["answer"]

# %%
# TODO: Add the tools you have defined and the instructions to your agent
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],    
    instructions=(
        "You are an Agentic RAG assistant that can intelligently decide which tools to use "
        "to answer user questions. Reason about about the response, change the query and call the tool again if needed "
        "in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers."
    )
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = I currently don't have real-time access to information about events occurring after my last training cut-off in October 2023, and the 2025 Oscars would be beyond that date. To find out the winner of the 2025 Oscar for International Movie, I recommend checking reliable news sources or the official Oscars website for the most current information. If you need any more information on past winners or related topics, feel free to ask!, tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_gBsViehYZ8kZA0b47Kg9LwtF', function=Function(arguments='{"query":"electric car exports Asia Pacific region 2024 excluding China"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, Japan and Korea accounted for the majority of the nearly 640,000 electric cars exported from the Asia Pacific region, excluding China, which represented an increase of 15% from 2023. The United States was the main destination for these exports, making up more than a quarter of the total production from the region. Europe followed as another significant market, importing another quarter of the region's electric car production.", tool_calls = None)
#  -> (role = assistant, content = In 2024, Japan and Korea accounted for most of the electric car exports from the Asia Pacific region, excluding China. They exported nearly 640,000 electric cars, reflecting a 15% increase from the previous year., tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "Why is generative AI seen more as an accelerator than a replacement in game development?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Why is generative AI seen more as an accelerator than a replacement in game development?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_EgkeHx1CofqdzqkownuYT8OA', function=Function(arguments='{"query":"generative AI accelerator replacement game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_a0IWLTBWn4tIPs7XryOOwqfy', function=Function(arguments='{"query":"generative AI impact on game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "Generative AI is having a significant impact on game development by enhancing various aspects of the gaming experience. It automates complex tasks, simulates intelligent behavior, and assists in creating dynamic and responsive non-player characters (NPCs). This leads to more realistic and immersive gaming environments, allowing games to react to players' actions in real-time. For example, in games like \"The Last of Us,\" AI capabilities enable opponents and companions to demonstrate realistic behaviors, adding depth to gameplay. Overall, AI is considered one of the most important innovations in modern gaming, contributing to the industry's growth and evolution.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageFunctionToolCall(id='call_vyjfMDZeooClTOb93eGH3ndK', function=Function(arguments='{"query":"generative AI role in game development"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "Generative AI plays a significant role in game development by enhancing the design, development, and overall gaming experience. It simulates intelligent behavior, automates complex tasks, and assists in creating dynamic and responsive non-player characters (NPCs), which contribute to more realistic and immersive gaming environments. For example, in games like \u201cThe Last of Us,\u201d AI enables opponents and companions to react in real-time to players' actions, adding depth and realism to gameplay. This integration of AI is considered one of the most important innovations in modern gaming, significantly impacting the $200 billion gaming industry.", tool_calls = None)
#  -> (role = assistant, content = Generative AI is seen more as an accelerator than a replacement in game development for several reasons:
#
# 1. **Enhancement of Creative Processes**: Generative AI automates complex tasks in game development, such as level design, character modeling, and environmental creation, allowing developers to focus on more creative aspects of game design. This accelerates the development process rather than replacing the creative roles of designers and artists.
#
# 2. **Dynamic and Responsive Game Features**: AI can simulate intelligent behavior for non-player characters (NPCs), making them react in real-time to players' actions. This capability adds depth and realism to gameplay, enhancing the overall gaming experience without taking away the human element of game design.
#
# 3. **Facilitation of Innovation**: By streamlining repetitive tasks and improving efficiency, generative AI enables developers to explore more innovative ideas and mechanics in their games. This leads to the creation of more engaging and immersive gaming environments.
#
# 4. **Support for Large-scale Projects**: In a rapidly evolving gaming industry, where budgets and timelines can be extensive, generative AI helps manage the workload by handling tasks that would otherwise require significant time and resources. This accelerative role is crucial in meeting the demands of modern game production.
#
# 5. **Collaboration with Human Creatives**: Rather than replacing human creativity, AI tools are designed to work alongside game developers, enhancing their capabilities and allowing them to produce higher-quality content more efficiently.
#
# In summary, generative AI is viewed as an accelerator in game development because it enhances productivity, fosters innovation, and collaborates with human creators to improve the overall quality of games, rather than replacing the essential human roles in the creative process., tool_calls = None)
